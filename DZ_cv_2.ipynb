# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16

print(tf.__version__)
print(tf.executing_eagerly())
# Out:
# 2.4.1
# True

# %% [markdown]
# ## Функции загрузки данных

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

train_files = glob('data/cats_dogs/train/*.jpg')
test_files = glob('data/cats_dogs/test/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Строим архитектуру сетки

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-1].output
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.LeakyReLU()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dropout(0.1)(x)
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='dogs_vs_cats')

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 25088)             0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25088)             100352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 25089
# =================================================================
# Total params: 14,840,129
# Trainable params: 75,265
# Non-trainable params: 14,764,864
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy', 'binary_crossentropy'])

# %%
val_samples = 10  # число изображений в валидационной выборке

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором

ckpt_path='cast_dogs_best.h5'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=ckpt_path,
    save_weights_only=True,
    monitor='val_binary_crossentropy',
    mode='min',
    save_best_only=True
)


# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=100,  # число эпох обучения
          validation_data=validation_data,
          callbacks=[model_checkpoint_callback]
         )

model.load_weights(ckpt_path)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 5s 333ms/step - loss: 0.6057 - accuracy: 0.7214 - binary_crossentropy: 0.5862 - val_loss: 0.7995 - val_accuracy: 0.9000 - val_binary_crossentropy: 0.7792
# Epoch 2/100
# 10/10 [==============================] - 2s 166ms/step - loss: 0.1829 - accuracy: 0.9240 - binary_crossentropy: 0.1622 - val_loss: 0.0678 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0464
# Epoch 3/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.1638 - accuracy: 0.9323 - binary_crossentropy: 0.1423 - val_loss: 0.0380 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0159
# Epoch 4/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1854 - accuracy: 0.9480 - binary_crossentropy: 0.1632 - val_loss: 0.0295 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0070
# Epoch 5/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1592 - accuracy: 0.9519 - binary_crossentropy: 0.1366 - val_loss: 0.0241 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0011
# Epoch 6/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1610 - accuracy: 0.9512 - binary_crossentropy: 0.1379 - val_loss: 0.0235 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.0364e-04
# Epoch 7/100
# 10/10 [==============================] - 2s 180ms/step - loss: 0.1314 - accuracy: 0.9658 - binary_crossentropy: 0.1079 - val_loss: 0.0239 - val_accuracy: 1.0000 - val_binary_crossentropy: 6.3784e-05
# Epoch 8/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.1384 - accuracy: 0.9574 - binary_crossentropy: 0.1145 - val_loss: 0.0243 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.1059e-04
# Epoch 9/100
# 10/10 [==============================] - 2s 173ms/step - loss: 0.1184 - accuracy: 0.9605 - binary_crossentropy: 0.0941 - val_loss: 0.0249 - val_accuracy: 1.0000 - val_binary_crossentropy: 3.4853e-04
# Epoch 10/100
# 10/10 [==============================] - 2s 177ms/step - loss: 0.1144 - accuracy: 0.9757 - binary_crossentropy: 0.0898 - val_loss: 0.0258 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0010
# Epoch 11/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.1270 - accuracy: 0.9708 - binary_crossentropy: 0.1021 - val_loss: 0.0270 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0018
# Epoch 12/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.1235 - accuracy: 0.9598 - binary_crossentropy: 0.0982 - val_loss: 0.0270 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0014
# Epoch 13/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.0978 - accuracy: 0.9679 - binary_crossentropy: 0.0721 - val_loss: 0.0271 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0011
# Epoch 14/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.1676 - accuracy: 0.9338 - binary_crossentropy: 0.1415 - val_loss: 0.0279 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0016
# Epoch 15/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1064 - accuracy: 0.9685 - binary_crossentropy: 0.0800 - val_loss: 0.0283 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0016
# Epoch 16/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.0843 - accuracy: 0.9714 - binary_crossentropy: 0.0575 - val_loss: 0.0282 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0011
# Epoch 17/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.1497 - accuracy: 0.9645 - binary_crossentropy: 0.1225 - val_loss: 0.0283 - val_accuracy: 1.0000 - val_binary_crossentropy: 7.4045e-04
# Epoch 18/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1400 - accuracy: 0.9537 - binary_crossentropy: 0.1124 - val_loss: 0.0348 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0070
# Epoch 19/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1357 - accuracy: 0.9677 - binary_crossentropy: 0.1078 - val_loss: 0.0341 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0059
# Epoch 20/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.0882 - accuracy: 0.9739 - binary_crossentropy: 0.0599 - val_loss: 0.0288 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.4939e-04
# Epoch 21/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.1225 - accuracy: 0.9634 - binary_crossentropy: 0.0939 - val_loss: 0.0289 - val_accuracy: 1.0000 - val_binary_crossentropy: 4.4414e-05
# Epoch 22/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.1292 - accuracy: 0.9535 - binary_crossentropy: 0.1002 - val_loss: 0.0293 - val_accuracy: 1.0000 - val_binary_crossentropy: 4.3805e-05
# Epoch 23/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.1761 - accuracy: 0.9459 - binary_crossentropy: 0.1467 - val_loss: 0.0297 - val_accuracy: 1.0000 - val_binary_crossentropy: 4.5040e-05
# Epoch 24/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.2404 - accuracy: 0.9632 - binary_crossentropy: 0.2107 - val_loss: 0.0302 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.0890e-04
# Epoch 25/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.1438 - accuracy: 0.9464 - binary_crossentropy: 0.1137 - val_loss: 0.0307 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.3722e-04
# Epoch 26/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.1455 - accuracy: 0.9673 - binary_crossentropy: 0.1149 - val_loss: 0.0309 - val_accuracy: 1.0000 - val_binary_crossentropy: 8.3063e-05
# Epoch 27/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1343 - accuracy: 0.9609 - binary_crossentropy: 0.1034 - val_loss: 0.0312 - val_accuracy: 1.0000 - val_binary_crossentropy: 7.0449e-05
# Epoch 28/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1553 - accuracy: 0.9769 - binary_crossentropy: 0.1241 - val_loss: 0.0315 - val_accuracy: 1.0000 - val_binary_crossentropy: 9.4396e-05
# Epoch 29/100
# 10/10 [==============================] - 2s 166ms/step - loss: 0.2191 - accuracy: 0.9518 - binary_crossentropy: 0.1876 - val_loss: 0.0319 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.0513e-04
# Epoch 30/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.2309 - accuracy: 0.9504 - binary_crossentropy: 0.1990 - val_loss: 0.0323 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.6987e-04
# Epoch 31/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.0607 - accuracy: 0.9877 - binary_crossentropy: 0.0285 - val_loss: 0.0326 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.0801e-04
# Epoch 32/100
# 10/10 [==============================] - 2s 178ms/step - loss: 0.1621 - accuracy: 0.9586 - binary_crossentropy: 0.1295 - val_loss: 0.0342 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0014
# Epoch 33/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.1852 - accuracy: 0.9534 - binary_crossentropy: 0.1523 - val_loss: 0.0451 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0120
# Epoch 34/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1232 - accuracy: 0.9631 - binary_crossentropy: 0.0899 - val_loss: 0.0347 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0011
# Epoch 35/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1124 - accuracy: 0.9526 - binary_crossentropy: 0.0787 - val_loss: 0.0346 - val_accuracy: 1.0000 - val_binary_crossentropy: 6.7061e-04
# Epoch 36/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.2011 - accuracy: 0.9643 - binary_crossentropy: 0.1670 - val_loss: 0.0344 - val_accuracy: 1.0000 - val_binary_crossentropy: 7.9577e-05
# Epoch 37/100
# 10/10 [==============================] - 2s 178ms/step - loss: 0.1521 - accuracy: 0.9590 - binary_crossentropy: 0.1177 - val_loss: 0.0347 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.7813e-05
# Epoch 38/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1498 - accuracy: 0.9657 - binary_crossentropy: 0.1150 - val_loss: 0.0351 - val_accuracy: 1.0000 - val_binary_crossentropy: 4.8510e-05
# Epoch 39/100
# 10/10 [==============================] - 2s 166ms/step - loss: 0.1998 - accuracy: 0.9379 - binary_crossentropy: 0.1646 - val_loss: 0.0355 - val_accuracy: 1.0000 - val_binary_crossentropy: 3.4889e-05
# Epoch 40/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.1836 - accuracy: 0.9583 - binary_crossentropy: 0.1481 - val_loss: 0.0359 - val_accuracy: 1.0000 - val_binary_crossentropy: 3.7109e-05
# Epoch 41/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1702 - accuracy: 0.9558 - binary_crossentropy: 0.1343 - val_loss: 0.0363 - val_accuracy: 1.0000 - val_binary_crossentropy: 9.1993e-05
# Epoch 42/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.1465 - accuracy: 0.9755 - binary_crossentropy: 0.1102 - val_loss: 0.0368 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.5323e-04
# Epoch 43/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1902 - accuracy: 0.9454 - binary_crossentropy: 0.1536 - val_loss: 0.0369 - val_accuracy: 1.0000 - val_binary_crossentropy: 6.6587e-05
# Epoch 44/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.1202 - accuracy: 0.9758 - binary_crossentropy: 0.0833 - val_loss: 0.0371 - val_accuracy: 1.0000 - val_binary_crossentropy: 4.2990e-05
# Epoch 45/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.1583 - accuracy: 0.9527 - binary_crossentropy: 0.1211 - val_loss: 0.0374 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.9593e-05
# Epoch 46/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.2162 - accuracy: 0.9541 - binary_crossentropy: 0.1788 - val_loss: 0.0376 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.9939e-05
# Epoch 47/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1657 - accuracy: 0.9528 - binary_crossentropy: 0.1280 - val_loss: 0.0380 - val_accuracy: 1.0000 - val_binary_crossentropy: 5.7263e-05
# Epoch 48/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.2413 - accuracy: 0.9403 - binary_crossentropy: 0.2032 - val_loss: 0.0384 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.1398e-04
# Epoch 49/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1978 - accuracy: 0.9540 - binary_crossentropy: 0.1594 - val_loss: 0.0388 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.5375e-04
# Epoch 50/100
# 10/10 [==============================] - 2s 173ms/step - loss: 0.1974 - accuracy: 0.9605 - binary_crossentropy: 0.1587 - val_loss: 0.0392 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.7925e-04
# Epoch 51/100
# 10/10 [==============================] - 2s 173ms/step - loss: 0.2608 - accuracy: 0.9377 - binary_crossentropy: 0.2218 - val_loss: 0.0394 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.6563e-04
# Epoch 52/100
# 10/10 [==============================] - 2s 173ms/step - loss: 0.1228 - accuracy: 0.9834 - binary_crossentropy: 0.0836 - val_loss: 0.0395 - val_accuracy: 1.0000 - val_binary_crossentropy: 4.6976e-05
# Epoch 53/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1016 - accuracy: 0.9832 - binary_crossentropy: 0.0621 - val_loss: 0.0397 - val_accuracy: 1.0000 - val_binary_crossentropy: 3.4781e-05
# Epoch 54/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.2880 - accuracy: 0.9555 - binary_crossentropy: 0.2483 - val_loss: 0.0400 - val_accuracy: 1.0000 - val_binary_crossentropy: 8.9069e-05
# Epoch 55/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.1937 - accuracy: 0.9502 - binary_crossentropy: 0.1537 - val_loss: 0.0405 - val_accuracy: 1.0000 - val_binary_crossentropy: 3.3325e-04
# Epoch 56/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.3615 - accuracy: 0.9271 - binary_crossentropy: 0.3212 - val_loss: 0.0405 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.0828e-05
# Epoch 57/100
# 10/10 [==============================] - 2s 177ms/step - loss: 0.1996 - accuracy: 0.9766 - binary_crossentropy: 0.1590 - val_loss: 0.0408 - val_accuracy: 1.0000 - val_binary_crossentropy: 3.8375e-06
# Epoch 58/100
# 10/10 [==============================] - 2s 177ms/step - loss: 0.2436 - accuracy: 0.9550 - binary_crossentropy: 0.2027 - val_loss: 0.0411 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.2235e-05
# Epoch 59/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.0567 - accuracy: 0.9994 - binary_crossentropy: 0.0156 - val_loss: 0.0416 - val_accuracy: 1.0000 - val_binary_crossentropy: 3.0401e-04
# Epoch 60/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.2331 - accuracy: 0.9596 - binary_crossentropy: 0.1918 - val_loss: 0.0415 - val_accuracy: 1.0000 - val_binary_crossentropy: 8.5695e-05
# Epoch 61/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.1675 - accuracy: 0.9537 - binary_crossentropy: 0.1261 - val_loss: 0.0416 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.6993e-05
# Epoch 62/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.0793 - accuracy: 0.9928 - binary_crossentropy: 0.0377 - val_loss: 0.0418 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.4994e-05
# Epoch 63/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.1373 - accuracy: 0.9720 - binary_crossentropy: 0.0955 - val_loss: 0.0419 - val_accuracy: 1.0000 - val_binary_crossentropy: 4.5829e-05
# Epoch 64/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.1606 - accuracy: 0.9738 - binary_crossentropy: 0.1187 - val_loss: 0.0421 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.6688e-05
# Epoch 65/100
# 10/10 [==============================] - 2s 178ms/step - loss: 0.1600 - accuracy: 0.9669 - binary_crossentropy: 0.1178 - val_loss: 0.0424 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.5784e-05
# Epoch 66/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.0808 - accuracy: 0.9883 - binary_crossentropy: 0.0384 - val_loss: 0.0426 - val_accuracy: 1.0000 - val_binary_crossentropy: 9.8888e-06
# Epoch 67/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.3515 - accuracy: 0.9611 - binary_crossentropy: 0.3089 - val_loss: 0.0429 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.7477e-04
# Epoch 68/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1953 - accuracy: 0.9689 - binary_crossentropy: 0.1525 - val_loss: 0.0472 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0043
# Epoch 69/100
# 10/10 [==============================] - 2s 180ms/step - loss: 0.1260 - accuracy: 0.9802 - binary_crossentropy: 0.0830 - val_loss: 0.0459 - val_accuracy: 1.0000 - val_binary_crossentropy: 0.0027
# Epoch 70/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1894 - accuracy: 0.9511 - binary_crossentropy: 0.1462 - val_loss: 0.0435 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.8550e-05
# Epoch 71/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1549 - accuracy: 0.9742 - binary_crossentropy: 0.1113 - val_loss: 0.0437 - val_accuracy: 1.0000 - val_binary_crossentropy: 8.9336e-06
# Epoch 72/100
# 10/10 [==============================] - 2s 180ms/step - loss: 0.2112 - accuracy: 0.9610 - binary_crossentropy: 0.1675 - val_loss: 0.0439 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.6145e-05
# Epoch 73/100
# 10/10 [==============================] - 2s 177ms/step - loss: 0.2722 - accuracy: 0.9546 - binary_crossentropy: 0.2282 - val_loss: 0.0442 - val_accuracy: 1.0000 - val_binary_crossentropy: 6.0675e-05
# Epoch 74/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1308 - accuracy: 0.9600 - binary_crossentropy: 0.0866 - val_loss: 0.0445 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.1186e-04
# Epoch 75/100
# 10/10 [==============================] - 2s 179ms/step - loss: 0.1001 - accuracy: 0.9723 - binary_crossentropy: 0.0557 - val_loss: 0.0447 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.0109e-04
# Epoch 76/100
# 10/10 [==============================] - 2s 176ms/step - loss: 0.0865 - accuracy: 0.9832 - binary_crossentropy: 0.0419 - val_loss: 0.0449 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.2007e-04
# Epoch 77/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.1166 - accuracy: 0.9728 - binary_crossentropy: 0.0718 - val_loss: 0.0450 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.2788e-04
# Epoch 78/100
# 10/10 [==============================] - 2s 173ms/step - loss: 0.2373 - accuracy: 0.9566 - binary_crossentropy: 0.1924 - val_loss: 0.0451 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.8628e-05
# Epoch 79/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.0703 - accuracy: 0.9906 - binary_crossentropy: 0.0252 - val_loss: 0.0453 - val_accuracy: 1.0000 - val_binary_crossentropy: 8.1224e-06
# Epoch 80/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.0781 - accuracy: 0.9970 - binary_crossentropy: 0.0328 - val_loss: 0.0454 - val_accuracy: 1.0000 - val_binary_crossentropy: 7.3812e-06
# Epoch 81/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.1435 - accuracy: 0.9800 - binary_crossentropy: 0.0981 - val_loss: 0.0455 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.9872e-05
# Epoch 82/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0644 - accuracy: 0.9962 - binary_crossentropy: 0.0188 - val_loss: 0.0457 - val_accuracy: 1.0000 - val_binary_crossentropy: 3.5079e-05
# Epoch 83/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1672 - accuracy: 0.9647 - binary_crossentropy: 0.1216 - val_loss: 0.0460 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.3952e-04
# Epoch 84/100
# 10/10 [==============================] - 2s 165ms/step - loss: 0.1620 - accuracy: 0.9736 - binary_crossentropy: 0.1162 - val_loss: 0.0461 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.2704e-04
# Epoch 85/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1335 - accuracy: 0.9711 - binary_crossentropy: 0.0876 - val_loss: 0.0460 - val_accuracy: 1.0000 - val_binary_crossentropy: 8.1040e-06
# Epoch 86/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1054 - accuracy: 0.9837 - binary_crossentropy: 0.0593 - val_loss: 0.0462 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.0787e-06
# Epoch 87/100
# 10/10 [==============================] - 2s 177ms/step - loss: 0.1783 - accuracy: 0.9728 - binary_crossentropy: 0.1321 - val_loss: 0.0463 - val_accuracy: 1.0000 - val_binary_crossentropy: 7.8539e-06
# Epoch 88/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.1655 - accuracy: 0.9735 - binary_crossentropy: 0.1192 - val_loss: 0.0465 - val_accuracy: 1.0000 - val_binary_crossentropy: 6.3415e-05
# Epoch 89/100
# 10/10 [==============================] - 2s 171ms/step - loss: 0.1144 - accuracy: 0.9838 - binary_crossentropy: 0.0680 - val_loss: 0.0467 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.3763e-04
# Epoch 90/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.0534 - accuracy: 0.9979 - binary_crossentropy: 0.0069 - val_loss: 0.0467 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.0478e-04
# Epoch 91/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0844 - accuracy: 0.9812 - binary_crossentropy: 0.0378 - val_loss: 0.0467 - val_accuracy: 1.0000 - val_binary_crossentropy: 6.0875e-05
# Epoch 92/100
# 10/10 [==============================] - 2s 178ms/step - loss: 0.2010 - accuracy: 0.9674 - binary_crossentropy: 0.1543 - val_loss: 0.0468 - val_accuracy: 1.0000 - val_binary_crossentropy: 5.9395e-05
# Epoch 93/100
# 10/10 [==============================] - 2s 186ms/step - loss: 0.0642 - accuracy: 0.9931 - binary_crossentropy: 0.0174 - val_loss: 0.0468 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.2173e-05
# Epoch 94/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.0618 - accuracy: 0.9969 - binary_crossentropy: 0.0149 - val_loss: 0.0469 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.8913e-05
# Epoch 95/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.1070 - accuracy: 0.9748 - binary_crossentropy: 0.0601 - val_loss: 0.0469 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.2882e-05
# Epoch 96/100
# 10/10 [==============================] - 2s 180ms/step - loss: 0.0656 - accuracy: 0.9902 - binary_crossentropy: 0.0188 - val_loss: 0.0469 - val_accuracy: 1.0000 - val_binary_crossentropy: 5.9976e-06
# Epoch 97/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.1901 - accuracy: 0.9675 - binary_crossentropy: 0.1431 - val_loss: 0.0470 - val_accuracy: 1.0000 - val_binary_crossentropy: 2.5919e-05
# Epoch 98/100
# 10/10 [==============================] - 2s 164ms/step - loss: 0.1294 - accuracy: 0.9782 - binary_crossentropy: 0.0824 - val_loss: 0.0474 - val_accuracy: 1.0000 - val_binary_crossentropy: 1.2594e-04
# Epoch 99/100
# 10/10 [==============================] - 2s 173ms/step - loss: 0.1119 - accuracy: 0.9808 - binary_crossentropy: 0.0646 - val_loss: 0.0481 - val_accuracy: 1.0000 - val_binary_crossentropy: 6.3330e-04
# Epoch 100/100
# 10/10 [==============================] - 2s 175ms/step - loss: 0.1121 - accuracy: 0.9751 - binary_crossentropy: 0.0646 - val_loss: 0.0481 - val_accuracy: 1.0000 - val_binary_crossentropy: 5.9746e-04

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files))

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %% [markdown]
# ## Готовим данные для отправки

# %%
import re

with open('submit.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))

# %%
from IPython.display import Image
Image('Romantsova.jpg')
